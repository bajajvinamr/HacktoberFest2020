# %% [markdown]
# # Selecting and Dwonloading 5000 of Phishing URLs and 5000 of Bnigan URLs
#
#
# *   In here, we collect Phishing URLs from http://data.phishtank.com/data/online-valid.csv and  select randomly 5000 URLs and save in to phishing.csv file
# *   Also, we collect Benigan URLs from https://www.unb.ca/cic/datasets/url-2016.html and  select randomly 5000 URLs from Benign_list_big_final.csv file  and save in to Benigan.csv file

# %%
#importing required packages for this Notebook

import pandas as pd
from google.colab import files

# %% [markdown]
# ### 1. Selecting and Creating Phishing URLs

# %%
# !wget http://data.phishtank.com/data/online-valid.csv
# Out:
# --2020-10-16 05:08:07--  http://data.phishtank.com/data/online-valid.csv
# Resolving data.phishtank.com (data.phishtank.com)... 104.16.101.75, 104.17.177.85, 2606:4700::6810:654b, ...
# Connecting to data.phishtank.com (data.phishtank.com)|104.16.101.75|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.phishtank.com/data/online-valid.csv [following]
# --2020-10-16 05:08:07--  https://data.phishtank.com/data/online-valid.csv
# Connecting to data.phishtank.com (data.phishtank.com)|104.16.101.75|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://d1750zhbc38ec0.cloudfront.net/datadumps/verified_online.csv?Expires=1602824897&Signature=hMTjVahKJTTwRb7qJW8ngAIc60180nK3sitKIcItS6LG-5R4uuNbPC6F0QPD9jcdWXfMdQOOktoLLiQuZTOnfIs6z~cCGrPAjoLhSBniX633WE7~~kTXVYJ~tFbRVlN3ZiBKk8-VgO5KlLCYPmUdctqBSy14N1DlAGhbM7aaQmCagnid1xlJlHqlOg0scMtVW0dsfU0dPZIdUiMpV3jxEEPZvEDfbU6aYy0pzd4wzrz3DYQUW7~~iIearAvx6OYBSONbSnLDKKu8sStuRZ5b6J484xuW7O4xMGcG~Horgjf851P-fT5IVhk9tZRmtUwf9F96sGqL52gxDA8dr-gpLA__&Key-Pair-Id=APKAILB45UG3RB4CSOJA [following]
# --2020-10-16 05:08:07--  https://d1750zhbc38ec0.cloudfront.net/datadumps/verified_online.csv?Expires=1602824897&Signature=hMTjVahKJTTwRb7qJW8ngAIc60180nK3sitKIcItS6LG-5R4uuNbPC6F0QPD9jcdWXfMdQOOktoLLiQuZTOnfIs6z~cCGrPAjoLhSBniX633WE7~~kTXVYJ~tFbRVlN3ZiBKk8-VgO5KlLCYPmUdctqBSy14N1DlAGhbM7aaQmCagnid1xlJlHqlOg0scMtVW0dsfU0dPZIdUiMpV3jxEEPZvEDfbU6aYy0pzd4wzrz3DYQUW7~~iIearAvx6OYBSONbSnLDKKu8sStuRZ5b6J484xuW7O4xMGcG~Horgjf851P-fT5IVhk9tZRmtUwf9F96sGqL52gxDA8dr-gpLA__&Key-Pair-Id=APKAILB45UG3RB4CSOJA
# Resolving d1750zhbc38ec0.cloudfront.net (d1750zhbc38ec0.cloudfront.net)... 99.84.232.39, 99.84.232.132, 99.84.232.159, ...
# Connecting to d1750zhbc38ec0.cloudfront.net (d1750zhbc38ec0.cloudfront.net)|99.84.232.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3019458 (2.9M) [text/csv]
# Saving to: ‘online-valid.csv’
#
# online-valid.csv    100%[===================>]   2.88M  2.92MB/s    in 1.0s
#
# 2020-10-16 05:08:09 (2.92 MB/s) - ‘online-valid.csv’ saved [3019458/3019458]

# %%
data0 = pd.read_csv("online-valid.csv")
data0.head()
# Out:
#    phish_id                                                url  ... online target
# 0   6810603                           https://ibsevenbenk.com/  ...    yes  Other
# 1   6810561  http://fbcom26471795.the222.ca/nextVRF.html?lo...  ...    yes  Other
# 2   6810553              http://lol0fi73845.000webhostapp.com/  ...    yes  Other
# 3   6810543  http://caseid-22606628.saasconsulting.ae/nextV...  ...    yes  Other
# 4   6810540  http://78.108.89.240/files/File/webmail_reset.htm  ...    yes  Other
#
# [5 rows x 8 columns]

# %%
data0.shape
# Out:
# (13822, 8)

# %%
phishurl = data0.sample(n = 5000, random_state = 12).copy()
phishurl = phishurl["url"]
phishurl = phishurl.reset_index(drop=True)
phishurl.head()
# Out:
# 0    https://secure.runescape.com-as.ru/m=weblogin/...
# 1                          http://kydeliver.pp.ua/auth
# 2                         http://coaltur.com/mode/home
# 3     https://online-banking.durmusdanis.com/Login.php
# 4    https://firebasestorage.googleapis.com/v0/b/su...
# Name: url, dtype: object

# %%
# Storing the extracted legitimate URLs fatures to csv file
phishurl.to_csv('1-phishurl.csv', index= False)
#downloading csv file to local machine
files.download('1-phishurl.csv')

# %% [markdown]
# ### 1. Selecting and Creating Benigan URLs

# %%
# Upload Benign_list_big_final.csv to Colab WorkSpace
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data1 = pd.read_csv("Benign_list_big_final.csv")
data1.columns = ['URLs']
data1.head()
# Out:
#                                                 URLs
# 0  http://1337x.to/torrent/1110018/Blackhat-2015-...
# 1  http://1337x.to/torrent/1122940/Blackhat-2015-...
# 2  http://1337x.to/torrent/1124395/Fast-and-Furio...
# 3  http://1337x.to/torrent/1145504/Avengers-Age-o...
# 4  http://1337x.to/torrent/1160078/Avengers-age-o...

# %%
#Collecting 5,000 Legitimate URLs randomly
legiurl = data1.sample(n = 5000, random_state = 12).copy()
legiurl = legiurl.reset_index(drop=True)
legiurl.shape
# Out:
# (5000, 1)

# %%
# Storing the extracted legitimate URLs fatures to csv file
legiurl.to_csv('2-beniganurl.csv', index= False)
#downloading csv file to local machine
files.download('2-beniganurl.csv')

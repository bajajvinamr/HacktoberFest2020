# %%
#importing required packages for this module
import pandas as pd
from google.colab import files

# %%
# Uploading 1-phishurl.csv file to Colab WorkSpace
files.upload()
# Out:
#      <input type="file" id="files-a3450c4f-a882-4593-ae3c-579600dd796f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3450c4f-a882-4593-ae3c-579600dd796f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1-phishurl.csv to 1-phishurl.csv
# {'1-phishurl.csv': b'url\n"https://secure.runescape.com-as.ru/m=weblogin/loginform303,70,794,82379556,1"\nhttp://kydeliver.pp.ua/auth\nhttp://coaltur.com/mode/home\nhttps://online-banking.durmusdanis.com/Login.php\nhttps://firebasestorage.googleapis.com/v0/b/sunupdatei00000.appspot.com/o/MMcc.htm?alt=media&amp;token=61ef2768-b25d-421d-950f-36f50acbc2a7#test@example.com\nhttp://owa.christexousia.com/\nhttps://boclog.com\nhttp://u7742171.ct.sendgrid.net/ls/click?upn=PWRqUU-2B969B8QatbL5mKJqoP7WWKCRg9j2qRTYdIxAMsOjC-2B5yyaLut6-2B3nMgfxf3yt8OO815niLsw1fpg-2FpuHqrZX5aGJRyVvP-2BIc0VlWoHT1hZUSb6HhuPo8Ua2qfGnMj00xMwvctLD5pgLU32WwXwNswMG0xtHoL6ezuUta6deI9eBYXSBE7GgQc7nDyyQhtsnGVgF-2FmcaNQ17l5NLDdwJYtFcobq-2F1wot4nVHqypml32DPvkXFNJMYjyW-2F033p6gcsGKuqUWKV4e-2BdLYTc-2BiUuasdVZqAC7sfgOp0XKFBQUzpqeqSsg2raORHJssdOW1gXLvjzjwiTreF71W2nHwltKKgW9SBHk46vJyj4xkbYFKvpy2gkWBtxxY79NeZt1DgKZve7CI5f9SPGJq6Gdu1-2B46Pta3UnlIWf8IYFEl0PbQ6nP234G-2F2YoHuzbr1oTtodtMIPhpwALABA84SXBiRsGA5l5f4PLL-2FydcnHk-3Dxhx4_HvtJSPMuI7hbvByHDx2LCukR23-2FDrPRvAfKpf95HiFiw8kMj7UX6ULJ6-2FHavmMAPyXVk3T-2BMUsUCv4j13DUN9MqxFUm2JwQdj-2FPcHkf7mJVTaSQlR35SFqEIJhT1iB1oE0VG5dXn8Qfn92iUTc8228zkpo2lzB4Kmuf6LrUjKf9OBJpx-2FAzrby20Hco51Wr0lkHfin18UQ-2Fg7bxBXbGX8syea-2FENjaQ-2Brt5ISU0c88U-3D\nhttp://consultax.cl/thecrowngroup/tcwoodinc/u.php\n"https://services.runescape.com-as.ru/m=weblogin/loginform934,762,777,15125644,2004"\nhttp://equalchances.org/net/page/myaccount/settings\nhttps://cxghdsf.yegdnmtd.top\nhttps://verif.pp-recouvrement-paiement.com/connexion\nhttps://store-lupa9npj4z.mybigcommerce.com/mpl/\nhttp://37.152.177.165/\nhttps://lcybur.fedmarfutsal.com/bzp?gh=ZIFwlWlnamKclYN0wHGXaHV1YKCDomZnaKZgY34/edgard_willems%40hotmail.com\nhttps://whisperingwoodsknuckles.com/netfli/login.orange.fr/orange_authen/customer-IDPP00C925/login.php\nhttps://ngx234.inmotionhosting.com/~neqwsn5/wp-content/themes/orange/johter/SBROCKER/card.php\nhttp://13.66.28.137/authflow/unsupported-browser/?redirectUri=/signin?returnUri=https://www.paypal.com/myaccount/\nhttp://logomine.co/address_on_envelope/dh\n"https://secure.runescape.com-as.ru/m=weblogin/loginform756,174,893,11226347,1"\nhttp://xh140.mjt.lu/lnk/AM8AAH761OAAAAAAAAAAAR4Z9CgAAAAAmToAAAAAABQ_NgBfWMTUW85hIPcBTPuVkxkKgqgmSQAUHiA/1/vd9v-tlkmvvmyagN8oZjyg/aHR0cHM6Ly9iaXQubHkvM2k4dEpVbA\nhttps://pbmjx.secureconnect.company/\nhttps://earthlinkhelpcenter.weebly.com/\nhttps://forms.office.com/Pages/ResponsePage.aspx?id=DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAAZ__gsF4_ZUOFRWV1IxS0FKWVZXVjhFMEkwMzRLVVBRRi4u\nhttp://site9434107.92.webydo.com/\nhttp://www.imusica.in/vendor/psy/psysh/src/Psy/Exceprmotin/container/confiig/error/comp/errorlog/pys/apo/3259413fb544452a5d9c6296786bb1a6/login.php\nhttp://halestelevision.co.uk/components/com_contact/cz/1c64199d79f10971b64695e5431751ca\nhttps://smbc.co.jp.sayjpi.cn\nhttp://aruba-iv.blogspot.com/\nhttps://zhsznvcmvhtgrmaveboyrtiksp-dot-gloff849483.uk.r.appspot.com/\nhttps://ctwazerbaijan.com/https\nhttp://email302.com/l/5fc15ea15e66c082e33c48babd5a8ff601a799e6/[email\xc2\xa0protected]tageapp.com/-/www.paypal.com/cgi-bin/\nhttp://onedrivedocument.ew.r.appspot.com/home.html\nhttp://clt1227564.bmetrack.com/c/l?u=A897CCF&amp;e=109A058&amp;c=12BB2C&amp;t=1&amp;email=ee1f0b62a4b9daf581e93634ceba065f%3D&amp;seq=1\nhttps://docs.google.com/forms/d/e/1FAIpQLSc5MdruUEQljnaQfDwyx2_VzupuqtaBMy4wvr-ousfBRehaCQ/viewform?usp=send_form\nhttps://u.to/g-7iGQ\nhttps://svkmmumbai-my.sharepoint.com/:x:/r/personal/pranjali_chandurkar_nmims_edu/_layouts/15/WopiFrame.aspx?guestaccesstoken=668CYp4S%2fWcmX8rj223bVJfwDVtrYffzfpyARbRUehA%3d&amp;docid=1_1916b69db182644fead12e874cad930c4&amp;wdFormId=%7BCD4093B9%2DDFAE%2D49F1%2DADDE%2DF32FBE93B271%7D&amp;action=formsubmit\nhttp://daotaoquoctedhxd.edu.vn/file/cp/daaum/login.php?cmd=login_submit&id=f78756d86e58981d71e2436d0a9c7275f78756d86e58981d71e2436d0a9c7275&session=f78756d86e58981d71e2436d0a9c7275f78756d86e58981d71e2436d0a9c7275\nhttps://ameonline24horas.ga/MeusProdutos/Prefetch.php?skullid=125770607\ ...

# %% [markdown]
# # **2.1. Phishing URLs:**

# %%
#loading the phishing URLs data to dataframe
phishurl = pd.read_csv("1-phishurl.csv")
phishurl.head()
# Out:
#                                                  url
# 0  https://secure.runescape.com-as.ru/m=weblogin/...
# 1                        http://kydeliver.pp.ua/auth
# 2                       http://coaltur.com/mode/home
# 3   https://online-banking.durmusdanis.com/Login.php
# 4  https://firebasestorage.googleapis.com/v0/b/su...

# %% [markdown]
# # **3.Feature Extraction**
# In this step,features are extracted from the URLs dataset.
# The extracted features are categorized into
#
#
# 1.   Address Bar based Features
# 2.   Domain based Features
# 3.   HTML & Javascript Features
#
# ## **3.1.Address Bar Based Features:**
# Many features can be extracted that can be consided as address bar base them, below mentioned were considered for this project.
#
#
# *   Domain of URL
# *   IP Address in URL
# *   "@"Symbol in URL
# * Length of URL
# * Depth of URL
# * Redirection "//" in URL
# * "http/https" in Domain name
# * Using URL Shortening Services "TinyURL"
# * Prefix or Suffix "-" in Domain
#
# Each of these features are explained and the coded below:

# %%
#importing required packages for this section
from urllib.parse import urlparse,urlencode
import ipaddress
import re

# %% [markdown]
# # **3.1.1.Domain of the URL**

# %%
# 1.Domain of the URL(Domain) 
def getDomain(url):
  domain = urlparse(url).netloc
  if re.match(r"^www.",domain):
       domain = domain.replace("www.","")
  return domain

# %% [markdown]
# # **3.1.2.IP Address in the URL**

# %%
# 2.Checks for IP address in URL (Have_IP)
def havingIP(url):
  try:
    ipaddress.ip_address(url)
    ip = 1
  except:
    ip = 0
  return ip

# %% [markdown]
# # **3.1.3. "@" Symbol in URL**

# %%
# 3.Checks the presence of @ in URL (Have_At)
def haveAtSign(url):
  if "@" in url:
    at = 1    
  else:
    at = 0    
  return at

# %% [markdown]
# # **3.1.4. Length of URL**

# %%
# 4.Finding the length of URL and categorizing (URL_Length)
def getLength(url):
  if len(url) < 54:
    length = 0            
  else:
    length = 1            
  return length

# %% [markdown]
# # **3.1.5. Depth of URL**

# %%
# 5.Gives number of '/' in URL (URL_Depth)
def getDepth(url):
  s = urlparse(url).path.split('/')
  depth = 0
  for j in range(len(s)):
    if len(s[j]) != 0:
      depth = depth+1
  return depth

# %% [markdown]
# # **3.1.6. Redirection "//" in URL**

# %%
# 6.Checking for redirection '//' in the url (Redirection)
def redirection(url):
  pos = url.rfind('//')
  if pos > 6:
    if pos > 7:
      return 1
    else:
      return 0
  else:
    return 0

# %% [markdown]
# # **3.1.7. "http/https" in Domain name**

# %%
# 7.Existence of “HTTPS” Token in the Domain Part of the URL (https_Domain)
def httpDomain(url):
  domain = urlparse(url).netloc
  if 'https' in domain:
    return 1
  else:
    return 0

# %% [markdown]
# # **3.1.8. Using URL Shortening Services “TinyURL”**

# %%
#listing shortening services
shortening_services = r"bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|" \
                      r"yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|" \
                      r"short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|" \
                      r"doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|db\.tt|" \
                      r"qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|q\.gs|is\.gd|" \
                      r"po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|x\.co|" \
                      r"prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|" \
                      r"tr\.im|link\.zip\.net"

# %%
# 8. Checking for Shortening Services in URL (Tiny_URL)
def tinyURL(url):
    match=re.search(shortening_services,url)
    if match:
        return 1
    else:
        return 0

# %% [markdown]
# # **3.1.9. Prefix or Suffix "-" in Domain**

# %%
# 9.Checking for Prefix or Suffix Separated by (-) in the Domain (Prefix/Suffix)
def prefixSuffix(url):
    if '-' in urlparse(url).netloc:
        return 1            # phishing
    else:
        return 0            # legitimate

# %% [markdown]
# ## **3.2. Domain Based Features:**
# Many features can be extracted that come under this category. Out of them, below mentioned were considered for this project.
#
#
# *  DNS Record
# * Website Traffic
# *Age of Domain
# *End Period of Domain

# %%
# !pip install python-whois
# Out:
# Collecting python-whois
#   Downloading https://files.pythonhosted.org/packages/4b/c6/85268f0cef6a1c7e466140437c8fe49eb12c203d9a31be6d2976a29c7266/python-whois-0.7.3.tar.gz (91kB)
#      |████████████████████████████████| 92kB 2.2MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-whois) (0.16.0)
# Building wheels for collected packages: python-whois
#   Building wheel for python-whois (setup.py) ... done
#   Created wheel for python-whois: filename=python_whois-0.7.3-cp36-none-any.whl size=87704 sha256=512cd3e4ab2a32016bbd442632ddfdbc953a976edf8ebb9ba92d1a531cc10dd9
#   Stored in directory: /root/.cache/pip/wheels/12/3c/9b/901b7deea1fa960f9abfd84df82414dff215c4a1d6869bcea2
# Successfully built python-whois
# Installing collected packages: python-whois
# Successfully installed python-whois-0.7.3

# %%
# importing required packages for this section
import re
from bs4 import BeautifulSoup
import whois
import urllib
import urllib.request
from datetime import datetime

# %% [markdown]
# **3.2.1.DNS Record**

# %%
# 11.DNS Record availability (DNS_Record)
# obtained in the featureExtraction function itself

# %% [markdown]
# **3.2.2. Web Traffic**

# %%
# 12.Web traffic (Web_Traffic)
def web_traffic(url):
  try:
    #Filling the whitespaces in the URL if any
    url = urllib.parse.quote(url)
    rank = BeautifulSoup(urllib.request.urlopen("http://data.alexa.com/data?cli=10&dat=s&url=" + url).read(), "xml").find(
        "REACH")['RANK']
    rank = int(rank)
  except TypeError:
        return 1
  if rank <100000:
    return 1
  else:
    return 0

# %% [markdown]
# **3.2.3. Age of Domain**

# %%
# 13.Survival time of domain: The difference between termination time and creation time (Domain_Age)  
def domainAge(domain_name):
  creation_date = domain_name.creation_date
  expiration_date = domain_name.expiration_date
  if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
    try:
      creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
      expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
    except:
      return 1
  if ((expiration_date is None) or (creation_date is None)):
      return 1
  elif ((type(expiration_date) is list) or (type(creation_date) is list)):
      return 1
  else:
    ageofdomain = abs((expiration_date - creation_date).days)
    if ((ageofdomain/30) < 6):
      age = 1
    else:
      age = 0
  return age

# %% [markdown]
# **3.2.4. End Period of Domain**

# %%
# 14.End time of domain: The difference between termination time and current time (Domain_End) 
def domainEnd(domain_name):
  expiration_date = domain_name.expiration_date
  if isinstance(expiration_date,str):
    try:
      expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
    except:
      return 1
  if (expiration_date is None):
      return 1
  elif (type(expiration_date) is list):
      return 1
  else:
    today = datetime.now()
    end = abs((expiration_date - today).days)
    if ((end/30) < 6):
      end = 0
    else:
      end = 1
  return end

# %% [markdown]
# # **3.3. HTML and JavaScript based Features**
# Many features can be extracted that come under this category. Out of them, below mentioned were considered for this project.
#
#
#
# *  IFrame Redirection
# *Status Bar Customization
# *Disabling Right Click
# *Website Forwarding

# %%
# importing required packages for this section
import requests

# %% [markdown]
# ### **3.3.1. IFrame Redirection**

# %%
# 15. IFrame Redirection (iFrame)
def iframe(response):
  if response == "":
      return 1
  else:
      if re.findall(r"[<iframe>|<frameBorder>]", response.text):
          return 0
      else:
          return 1

# %% [markdown]
# ### **3.3.2. Status Bar Customization**

# %%
# 16.Checks the effect of mouse over on status bar (Mouse_Over)
def mouseOver(response): 
  if response == "" :
    return 1
  else:
    if re.findall("<script>.+onmouseover.+</script>", response.text):
      return 1
    else:
      return 0

# %% [markdown]
# ### **3.3.3. Disabling Right Click**

# %%
# 17.Checks the status of the right click attribute (Right_Click)
def rightClick(response):
  if response == "":
    return 1
  else:
    if re.findall(r"event.button ?== ?2", response.text):
      return 0
    else:
      return 1

# %% [markdown]
# ### **3.3.4. Website Forwarding**

# %%
# 18.Checks the number of forwardings (Web_Forwards)    
def forwarding(response):
  if response == "":
    return 1
  else:
    if len(response.history) <= 2:
      return 0
    else:
      return 1

# %% [markdown]
# ## **4. Computing URL Features**

# %%
#Function to extract features
def featureExtraction(url,label):

  features = []
  #Address bar based features (10)
  features.append(getDomain(url))
  features.append(havingIP(url))
  features.append(haveAtSign(url))
  features.append(getLength(url))
  features.append(getDepth(url))
  features.append(redirection(url))
  features.append(httpDomain(url))
  features.append(tinyURL(url))
  features.append(prefixSuffix(url))
  
  #Domain based features (4)
  dns = 0
  try:
    domain_name = whois.whois(urlparse(url).netloc)
  except:
    dns = 1

  features.append(dns)
  features.append(web_traffic(url))
  features.append(1 if dns == 1 else domainAge(domain_name))
  features.append(1 if dns == 1 else domainEnd(domain_name))
  
  # HTML & Javascript based features (4)
  try:
    response = requests.get(url)
  except:
    response = ""
  features.append(iframe(response))
  features.append(mouseOver(response))
  features.append(rightClick(response))
  features.append(forwarding(response))
  features.append(label)
  
  return features

# %% [markdown]
# ### **4.2. Reviewing Phishing URLs:**

# %%
phishurl.shape
# Out:
# (5000, 1)

# %% [markdown]
# We will Reviewing URls 2500 by 2500 and storing seperate files and merge them.

# %%
feature_names = ['Domain', 'Have_IP', 'Have_At', 'URL_Length', 'URL_Depth','Redirection', 
                      'https_Domain', 'TinyURL', 'Prefix/Suffix', 'DNS_Record', 'Web_Traffic', 
                      'Domain_Age', 'Domain_End', 'iFrame', 'Mouse_Over','Right_Click', 'Web_Forwards', 'Label']

label = 1

# %% [markdown]
# 0 - 2500 phishing URLs

# %%
#Extracting the feautres & storing them in a list
phish_features = []

for i in range(0, 2500):
  url = phishurl['url'][i]
  print(i)
  phish_features.append(featureExtraction(url,label))

# %%
#converting the list to dataframe
phishing = pd.DataFrame(phish_features, columns= feature_names)
phishing.head()

# %%
# Storing the extracted legitimate URLs fatures to csv file
phishing.to_csv('3-phishing.csv', index= False)
#downloading csv file to local machine
files.download('3-phishing.csv')

# %% [markdown]
# 2500 - 5000 phishing URLs

# %%
#Extracting the feautres & storing them in a list
phish_features = []

for i in range(0, 2500):
  url = phishurl['url'][i]
  print(i)
  phish_features.append(featureExtraction(url,label))

# %%
#converting the list to dataframe
phishing = pd.DataFrame(phish_features, columns= feature_names)
phishing.head()

# %%
# Storing the extracted legitimate URLs fatures to csv file
phishing.to_csv('4-phishing.csv', index= False)
#downloading csv file to local machine
files.download('4-phishing.csv')
